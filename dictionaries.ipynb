# %%
myinfo = ["Noha", 33, "iti","Mansoura" ]
# un-labeled
# add description for the data
# introduce new datatype mutable  --> called dict??

# %%
# datatype
# set ??
# no duplication
# un-ordered
# no reference for the item
mys = {"iti", "mansoura", 2423, "iti", True, "iti", True, "new"}
print(mys)
# Out:
# {True, 2423, 'new', 'iti', 'mansoura'}

# %%
# mutable datatype
mys.add("new element")
print(mys)
# Out:
# {True, 'new element', 2423, 'new', 'iti', 'mansoura'}

# %%
mys2 = {"new", ("python", 'sql'), 214}
print(mys2)
# Out:
# {'new', 214, ('python', 'sql')}

# %%
mys2 = {"new", ["python", 'sql'], 214}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 mys2 = {"new", ["python", 'sql'], 214}
#
# TypeError: unhashable type: 'list'

# %%
# dict
"""
comma seperated key value pair
--> key--> unique

info = {
"name": "noha",
"age": 33,
"track" : "bi"
}
"""
info = {
"name": "noha",
"age": 33,
"track" : "bi"
}

# %%
# access dict elements, using key --> unique ??
print(info["name"])
# Out:
# noha

# %%
info["name"] = "Noha Shehab" # update

# %%
info["city"]= "Mansoura" # insert new key

# %%
# dict  --> ordered datatype  --> hashing keys -> speed up data
dd = {
    ["new", "iti"]: "Test"
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 # dict  --> ordered datatype  --> hashing keys -> speed up data
# ----> 2 dd = {
#       3     ["new", "iti"]: "Test"
#       4 }
#
# TypeError: unhashable type: 'list'

# %%
dd = {
    ("new", "iti"): "Test"
}

# %%
dd2 = {
    ("new", "iti"): "Test",
    ("new", "iti"): "TTTT",

}
print(dd2)
# Out:
# {('new', 'iti'): 'TTTT'}

# %%
print(info)
# Out:
# {'name': 'Noha Shehab', 'age': 33, 'track': 'bi', 'city': 'Mansoura'}

# %%
# get keys ?
keys =info.keys()
print(keys)  # dict_keys
# Out:
# dict_keys(['name', 'age', 'track', 'city'])

# %%
keys = list(keys)
print(keys)
# Out:
# ['name', 'age', 'track', 'city']

# %%
values = info.values() # dict_values

# %%
print(values)
values = list(values)
print(values)
# Out:
# dict_values(['Noha Shehab', 33, 'bi', 'Mansoura'])
# ['Noha Shehab', 33, 'bi', 'Mansoura']

# %%
items = info.items()
print(items)
# Out:
# dict_items([('name', 'Noha Shehab'), ('age', 33), ('track', 'bi'), ('city', 'Mansoura')])

# %%
items_l = list(items)
print(items_l)
# Out:
# [('name', 'Noha Shehab'), ('age', 33), ('track', 'bi'), ('city', 'Mansoura')]

# %%
print(info)
# Out:
# {'name': 'Noha Shehab', 'age': 33, 'track': 'bi', 'city': 'Mansoura'}

# %%
print("Mansoura" in info) # check in keys
# Out:
# False

# %%
print("Mansoura" in info.values()) # check in keys
# Out:
# True

# %%
for item in info:  # keys
    print(f"item: {item}")
# Out:
# item: name
# item: age
# item: track
# item: city

# %%
for k, v in info.items(): print(k, v)
# Out:
# name Noha Shehab
# age 33
# track bi
# city Mansoura

# %%
# update the dict ??
add_info = {"hoppy": "reading", "grad_year":2014, "name": "Noha"}

info.update(add_info)
print(add_info)
# Out:
# {'hoppy': 'reading', 'grad_year': 2014, 'name': 'Noha'}

# %%
print(info)
# Out:
# {'name': 'Noha', 'age': 33, 'track': 'bi', 'city': 'Mansoura', 'hoppy': 'reading', 'grad_year': 2014}

# %%
print(len(info))
# Out:
# 6

# %%
for index, item in enumerate(info):
    print(index, item)
# Out:
# 0 name
# 1 age
# 2 track
# 3 city
# 4 hoppy
# 5 grad_year

# %%
for index, item in enumerate(info.values()):
    print(index, item)
# Out:
# 0 Noha
# 1 33
# 2 bi
# 3 Mansoura
# 4 reading
# 5 2014

# %%
for index, item in enumerate(info.items()):
    print(index, item)
# Out:
# 0 ('name', 'Noha')
# 1 ('age', 33)
# 2 ('track', 'bi')
# 3 ('city', 'Mansoura')
# 4 ('hoppy', 'reading')
# 5 ('grad_year', 2014)

# %%
popped_value=info.pop("city")
print(popped_value, info)
# Out:
# Mansoura {'name': 'Noha', 'age': 33, 'track': 'bi', 'hoppy': 'reading', 'grad_year': 2014}

# %%
del info["age"]

# %%
info.clear()
