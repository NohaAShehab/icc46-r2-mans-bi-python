# %% [markdown]
# <h1 style='color:red; text-align:center'>String operations  </h1>

# %% [markdown]
# ---
#
# <h2 style='color:#2E86AB; border-left: 4px solid #2E86AB; padding-left: 10px;'>🔒 String Immutability</h2>
#
# <div style='background-color:#E8F4F8; padding: 15px; border-radius: 5px; border-left: 4px solid #2E86AB; margin: 10px 0;'>
# <strong style='color:#1B5E7E;'>💡 Key Concept:</strong> Any operation applied on a string returns a <strong style='color:#C2185B;'>new string</strong>.
# </div>
#
# <p style='color:#333; font-size: 16px;'>Strings are <strong style='color:#C2185B;'>immutable</strong> data types in Python - once created, they cannot be changed. This means when you perform operations like slicing, replacing, or modifying a string, Python creates a new string object rather than modifying the original one.</p>
#
# <div style='background-color:#FFF3E0; padding: 10px; border-radius: 5px; margin: 10px 0;'>
# <strong style='color:#E65100;'>Example:</strong>
# <pre style='background-color:#263238; color:#A8DADC; padding: 10px; border-radius: 3px;'><code>text = "Hello"
# new_text = text.upper()  # Creates a NEW string
# # 'text' remains unchanged: "Hello"</code></pre>
# </div>

# %% [markdown]
# ---
#
# <h2 style='color:#6A4C93; border-left: 4px solid #6A4C93; padding-left: 10px;'>📝 Working with Strings</h2>
#
# <p style='color:#555; font-size: 16px;'>Let's start by creating a sample string to work with:</p>

# %%
iti = "Information technology institute"

# %% [markdown]
# ---
#
# <h2 style='color:#F77F00; border-left: 4px solid #F77F00; padding-left: 10px;'>🔪 String Slicing Basics</h2>
#
# <p style='color:#333; font-size: 16px;'>Slicing allows you to extract portions of a string using the syntax:</p>
#
# <div style='background-color:#FFF8E1; padding: 15px; border-radius: 5px; margin: 10px 0;'>
# <pre style='background-color:#1A1A1A; color:#4ECDC4; padding: 15px; border-radius: 5px; border-left: 4px solid #F77F00;'><code>string[start:end]  # end index is EXCLUDED</code></pre>
# </div>
#
# <div style='background-color:#E3F2FD; padding: 15px; border-radius: 5px; margin: 10px 0;'>
# <strong style='color:#1565C0;'>Key Points:</strong>
# <ul style='color:#555;'>
# <li>Indexes start from <strong style='color:#C2185B;'>0</strong> (zero-based indexing)</li>
# <li>The <code style='background-color:#FFE0B2; padding: 2px 6px; border-radius: 3px;'>end</code> index is <strong style='color:#C2185B;'>excluded</strong> from the result</li>
# <li>Negative indexes count from the end of the string</li>
# </ul>
# </div>

# %%
# 1- get len ?
print(len(iti))
# Out:
# 32

# %%
#2- access string parts using index start form 0
print(iti[4])
# Out:
# r

# %% [markdown]
# ---
#
# <h3 style='color:#D32F2F; border-left: 4px solid #D32F2F; padding-left: 10px;'>⏭️ Slicing with Step Value</h3>
#
# <p style='color:#333; font-size: 16px;'>You can add a third parameter to control the step size:</p>
#
# <div style='background-color:#FFEBEE; padding: 15px; border-radius: 5px; margin: 10px 0;'>
# <pre style='background-color:#1A1A1A; color:#FF6B6B; padding: 15px; border-radius: 5px; border-left: 4px solid #D32F2F;'><code>string[start:end:step]</code></pre>
# </div>
#
# <ul style='color:#555; background-color:#FCE4EC; padding: 15px; border-radius: 5px;'>
# <li><strong style='color:#C2185B;'>Step of 2</strong> = take every 2nd character</li>
# <li><strong style='color:#C2185B;'>Step of -1</strong> = reverse the string</li>
# <li><strong style='color:#C2185B;'>Step of 3</strong> = take every 3rd character</li>
# </ul>

# %%
print(iti[4:15]) # exclude the last index
# Out:
# rmation tec

# %% [markdown]
# i

# %%
print(iti[4:])
# Out:
# rmation technology institute

# %%
print(iti[4::2])
# Out:
# raintcnlg nttt

# %% [markdown]
# Now let's see the code in action:

# %%
print(iti[::])
# Out:
# Information technology institute

# %%
### Reversing a string

Using a negative step value `[::-1]` reverses the string.
# Out:
# etutitsni ygolonhcet noitamrofnI

# %% [markdown]
# ul

# %%
# iti = iti[3:19]  # re-assign

# %% [markdown]
# ---
#
# ### 🔁 String Repetition
#
# You can use the `*` operator to repeat strings multiple times:
#
# ```python
# text = "Hello "
# repeated = text * 3  # "Hello Hello Hello "
# ```

# %%
## 4. String Methods - Counting Characters

The `count()` method returns the number of times a specific character or substring appears in the string.
# Out:
# 3

# %%
## 5. Finding Character Index

The `index()` method returns the index of the **first occurrence** of a character or substring in the string.
# Out:
# 8

# %% [markdown]
# ## 6. String Formatting
#
# There are several ways to format strings in Python. Let's explore different methods:

# %%
### Method 1: String Concatenation

The simplest way to combine strings is using the `+` operator. This joins strings together.
# Out:
# noha abdelhady shehab

# %%
fullname = fname + " "+midname + " "+ midname + " "+ lname
print(fullname)
# Out:
# noha abdelhady abdelhady shehab

# %%
### String Repetition

You can use the `*` operator to repeat strings. This is useful for string interpolation and formatting.
# Out:
# noha abdelhady abdelhady shehab

# %% [markdown]
# ---
#
# <h2 style='color:#9C27B0; border-left: 4px solid #9C27B0; padding-left: 10px; background: linear-gradient(90deg, #E1BEE7 0%, #FFFFFF 100%); padding: 15px; border-radius: 5px;'>🎨 String Formatting Methods</h2>
#
# <h3 style='color:#7B1FA2; border-left: 4px solid #7B1FA2; padding-left: 10px; margin-top: 20px;'>Method 1: Using <code style='background-color:#F3E5F5; padding: 2px 6px; border-radius: 3px; color:#4A148C;'>.format()</code></h3>
#
# <p style='color:#333; font-size: 16px;'>The <code style='background-color:#F3E5F5; padding: 2px 6px; border-radius: 3px; color:#4A148C;'>.format()</code> method allows you to insert values into placeholders:</p>
#
# <div style='background-color:#F3E5F5; padding: 15px; border-radius: 5px; margin: 10px 0;'>
# <pre style='background-color:#1A1A1A; color:#CE93D8; padding: 15px; border-radius: 5px; border-left: 4px solid #9C27B0;'><code>template = "we have {0} students in {1} track"
# result = template.format(30, "BI")</code></pre>
# </div>
#
# <div style='background-color:#E8EAF6; padding: 15px; border-radius: 5px; margin: 10px 0;'>
# <strong style='color:#3F51B5;'>Placeholder Types:</strong>
# <ul style='color:#555;'>
# <li><strong style='color:#5C6BC0;'>Positional:</strong> <code style='background-color:#C5CAE9; padding: 2px 6px; border-radius: 3px;'>{0}</code>, <code style='background-color:#C5CAE9; padding: 2px 6px; border-radius: 3px;'>{1}</code>, <code style='background-color:#C5CAE9; padding: 2px 6px; border-radius: 3px;'>{2}</code> - numbers correspond to argument order</li>
# <li><strong style='color:#5C6BC0;'>Named:</strong> <code style='background-color:#C5CAE9; padding: 2px 6px; border-radius: 3px;'>{name}</code>, <code style='background-color:#C5CAE9; padding: 2px 6px; border-radius: 3px;'>{age}</code> - use keyword arguments</li>
# </ul>
# </div>

# %% [markdown]
# ---
#
# ## 🔤 Case Conversion Methods
#
# Python provides several methods to change the case of strings. These methods return **new strings** (remember, strings are immutable).
#
# **Available Methods:**
# - `capitalize()` - First character uppercase, rest lowercase
# - `title()` - First letter of each word uppercase
# - `upper()` - All characters uppercase
# - `lower()` - All characters lowercase

# %% [markdown]
# ## 7. Case Conversion Methods
#
# Python provides several methods to change the case of strings. These methods return **new strings** (remember, strings are immutable).

# %% [markdown]
# ---
#
# ### Examples of Case Conversion
#
# Let's see each method in action:

# %% [markdown]
# ---
#
# > **⚠️ Important:** The order matters!
#
# If you swap the arguments, the values will be inserted in the wrong positions:
#
# ```python
# template = "we have {0} students in {1} track"
# result = template.format("BI", 30)  # ❌ Wrong order!
# # Result: "we have BI students in 30 track"
# ```

# %%
print(fullname.capitalize()) # return new string ==> first char --> Capital
# Out:
# Noha abdelhady abdelhady shehab

# %% [markdown]
# ---
#
# > **💡 Remember:** All these methods return **new strings** - they don't modify the original!

# %% [markdown]
# ---
#
# > **❌ Error:** This won't work!
#
# We're using **named placeholders** but passing **positional arguments**.
#
# **Solution:** Use keyword arguments when using named placeholders:
#
# ```python
# template = "we have {stds_num} students in {trk_name} track"
# result = template.format(stds_num=30, trk_name="BI")  # ✅ Correct!
# ```

# %%
print(fullname.title())
# Out:
# Noha Abdelhady Abdelhady Shehab

# %%
print(fullname.upper())
# Out:
# NOHA ABDELHADY ABDELHADY SHEHAB

# %% [markdown]
# ---
#
# ### Method 2: F-Strings (Formatted String Literals) ✨
#
# F-strings are a **modern and preferred** way to format strings in Python 3.6+.
#
# **Syntax:**
# ```python
# f"Text {variable} more text {expression}"
# ```
#
# **Advantages:**
# - More readable and concise
# - Faster than `.format()`
# - Can include expressions directly

# %% [markdown]
# ---
#
# > **❌ Error:** This will fail!
#
# The variable `age` is not defined yet. Variables must exist before being used in f-strings.
#
# **Fix:** Define the variable first, then use it in the f-string.

# %% [markdown]
# ---
#
# ## 🔄 String Replacement
#
# ### Method 1: Manual Replacement (Using Loop)
#
# Here's a manual approach to replace characters using a loop:
#
# ```python
# # Iterate through each character
# # Replace matching characters
# # Build new string
# ```
#
# **Note:** This is less efficient than using built-in methods.

# %% [markdown]
# ---
#
# ### Method 2: Using `.replace()` Method ⚡
#
# The `.replace()` method is **much simpler and more efficient**:
#
# ```python
# text.replace(old, new)  # Replace all occurrences
# text.replace(old, new, count)  # Replace first 'count' occurrences
# ```
#
# **Advantages:**
# - ✅ One line of code
# - ✅ More efficient
# - ✅ Built-in and optimized

# %% [markdown]
# ---
#
# > **💡 Tip:** You can limit the number of replacements!
#
# Specify a third parameter `count` to replace only the first N occurrences:
#
# ```python
# text.replace("o", "@", 2)  # Replace only first 2 occurrences
# ```

# %% [markdown]
# ## format string --> format, f- function

# %%
num_of_students = 30
temp = "we have" + num_of_students + "students in BI track"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 num_of_students = 30
# ----> 2 temp = "we have" + num_of_students + "students in BI track"
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ---
#
# ## ⌨️ User Input
#
# > **⚠️ Important:** The `input()` function **always returns a string**, even if the user enters a number!
#
# ```python
# user_input = input("Enter a number: ")  # Returns string!
# print(type(user_input))  # <class 'str'>
# ```
#
# **To use as a number, you must convert it:**
# ```python
# num = int(input("Enter a number: "))
# ```

# %%
num_of_students = 30
temp = "we have " + str(num_of_students) + " students in BI track"
print(temp)
# Out:
# we have 30 students in BI track

# %% [markdown]
# ---
#
# > **⚠️ Common Mistake:** String Concatenation vs Addition
#
# When you use `+` on two strings from `input()`, they are **concatenated**, not added mathematically!
#
# ```python
# num1 = input("Enter num1: ")  # "3" (string)
# num2 = input("Enter num2: ")  # "3" (string)
# result = num1 + num2  # "33" (concatenated, not 6!)
# ```

# %% [markdown]
# ---
#
# > **✅ Solution:** Convert strings to numbers!
#
# To perform mathematical operations, you must convert the strings to numbers:
#
# ```python
# num1 = int(input("Enter num1: "))
# num2 = int(input("Enter num2: "))
# result = num1 + num2  # Now it's addition: 3 + 3 = 6
# ```

# %%
num_of_students = 30
temp = "we have {0} students in {1} track"
print(temp, type(temp))
# Out:
# we have {0} students in {1} track <class 'str'>

# %%
print(temp.format(30, "BI")) # return new string
# Out:
# we have 30 students in BI track

# %% [markdown]
# ---
#
# ## ✅ String Validation Methods
#
# Python provides several methods to check the content of strings:
#
# | Method | Description | Example |
# |--------|-------------|---------|
# | `isdigit()` | Returns `True` if all characters are digits | `"123".isdigit()` → `True` |
# | `isspace()` | Returns `True` if all characters are whitespace | `"   ".isspace()` → `True` |
# | `isascii()` | Returns `True` if all characters are ASCII | `"Hello".isascii()` → `True` |
#
# **Use Case:** Validate user input before processing!

# %%
print(temp.format("BI", 30))
# Out:
# we have BI students in 30 track

# %%
temp2 = "we have {stds_num} students in {trk_name} track"
print(temp2, type(temp2))
# Out:
# we have {stds_num} students in {trk_name} track <class 'str'>

# %%
print(temp2.format("BI", 30))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 print(temp2.format("BI", 30))
#
# KeyError: 'stds_num'

# %%
print(temp2.format(stds_num= 30, trk_name= "BI"))
# Out:
# we have 30 students in BI track

# %% [markdown]
# ---
#
# ## ✂️ Stripping Whitespace
#
# The `rstrip()` method removes whitespace (or specified characters) from the **right end** of a string.
#
# **Related Methods:**
# - `rstrip()` - Remove from right
# - `lstrip()` - Remove from left
# - `strip()` - Remove from both ends

# %% [markdown]
# ---
#
# > **💡 Custom Characters:** You can specify which characters to strip!
#
# ```python
# text = "@     welcome     @"
# text.rstrip("@")  # Removes only '@' from the right
# ```
#
# **Note:** Only removes characters from the **end** of the string.

# %% [markdown]
# ---
#
# > **⚠️ Important:** `rstrip()` only removes characters from the **end**!
#
# If the specified characters are not at the end, nothing is removed:
#
# ```python
# text = "  welcome  $  "
# text.rstrip("@$")  # Nothing removed (no @ or $ at the end)
# ```

# %% [markdown]
# ---
#
# ## 🔍 The `in` Operator
#
# The `in` operator checks if a character or substring exists within a string.
#
# **Returns:** `True` or `False`
#
# **Syntax:**
# ```python
# "substring" in "string"  # Returns True or False
# ```
#
# **Example:**
# ```python
# "n" in "noha"  # True
# "x" in "noha"  # False
# ```

# %% [markdown]
# # f-format

# %%
# I need to format string based on existing variables
fname= 'noha'
lname = 'shehab'
msg = f"My name is {fname} {lname} {age}"
print(msg)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 4
#       2 fname= 'noha'
#       3 lname = 'shehab'
# ----> 4 msg = f"My name is {fname} {lname} {age}"
#       5 print(msg)
#
# NameError: name 'age' is not defined

# %%
age = 33
msg = f"My name is {fname} {lname} {age}"
print(msg)
# Out:
# My name is noha shehab 33

# %%
message = "We do love python much."
newstring = ""
# replace o with @

for abbass in message:
    # print(abbass)
    if abbass=='o':
        newstring +='@'
    else:
        newstring += abbass

print(newstring)
# Out:
# We d@ l@ve pyth@n much.

# %%
newmessage = message.replace("o", "@")
print(newmessage)
# Out:
# We d@ l@ve pyth@n much.

# %%
newmessage = message.replace("o", "@",2)
print(newmessage)
# Out:
# We d@ l@ve python much.

# %%
numm = "10.2425"

if float(numm) > int(numm):
    print("-- contain float")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 3
#       1 numm = "10.2425"
# ----> 3 if float(numm) > int(numm):
#       4     print("-- contain float")
#
# ValueError: invalid literal for int() with base 10: '10.2425'

# %% [markdown]
# # ask user to enter value

# %%
message = input("please enter message: ")  # accept user input into a string
print(type(message), message)
# Out:
# <class 'str'> 10

# %%
num1 = input("please enter num1 : ")
num2 = input("please enter num2 : ")
res = num1 + num2
print(res )
# Out:
# 33hello

# %%
num1 = input("please enter num1 : ")
num2 = input("please enter num2 : ")
res = int(num1) + int(num2)
print(res )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[41], line 3
#       1 num1 = input("please enter num1 : ")
#       2 num2 = input("please enter num2 : ")
# ----> 3 res = int(num1) + int(num2)
#       4 print(res )
#
# ValueError: invalid literal for int() with base 10: 'ewr'

# %% [markdown]
# <img src='userinput.jpeg'>

# %%
num = input("please enter number: ")
if num.isdigit(): # return true if content of num is only digits 083214
    num = int(num)
    val = num * 10
    print(f"--= num * 10 = {val}")

# %%
username = input("please enter username: ")
if username.isspace():
    print("-- please enter valid username")
# Out:
# -- please enter valid username

# %%
print("Hello ااب".isascii())
# Out:
# False

# %% [markdown]
# ### strip string

# %%
greet = "      welcome to day01     "
print(len(greet))
greet = greet.rstrip()
print(greet)
print(len(greet))
# Out:
# 27
#       welcome to day01
# 22

# %%
greet = "      welcome to day01     "
print(len(greet))
greet = greet.rstrip() # strip white space
print(greet)
print(len(greet))

# %%
greet = "@     welcome to day01     @"
print(len(greet))
greet = greet.rstrip("@") # strip white space
print(greet)
print(len(greet))
# Out:
# 28
# @     welcome to day01
# 27

# %%
greet = "      welcome to day01.  $   "
print(len(greet))
greet = greet.rstrip("@$") # strip white space
print(greet)
print(len(greet))
# Out:
# 29
#       welcome to day01.  $
# 29

# %%
# check if char exists in string ? -- in operator

if "n" in "noha":
    print("found")
# Out:
# found

# %%
# if char  in "aeiou":
#     pass

# noha ===> nh
