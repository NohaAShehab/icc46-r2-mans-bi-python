# %%
print("hello")
# Out:
# hello

# %%
#1- define a list ?

l = []
myl = list()

# %%
#2- list can hold different values from different datatypes ?
l = ["iti", "BI",3214, None, 444.33, True, "iti", ['db', 'python', 'power bi', 'freelancing'], "iti"]

# %% [markdown]
# <h1 style='color:orange; text-align:center'> Slicing List  </h1>
# return new list

# %%
#3- check this
print(l[2])
# Out:
# 3214

# %%
print(l[2:5])
# Out:
# [3214, None, 444.33]

# %%
print(l[::2])

# %%
print(l[::-1])
# Out:
# ['iti', ['db', 'python', 'power bi', 'freelancing'], 'iti', True, 444.33, None, 3214, 'BI', 'iti']

# %% [markdown]
# ## list is mutable datatype ?
# -  add/ remove elements
# -  sort elements
# -  update elements
# - list is non hashable datatype

# %%
l[3]="updated"

# %%
print(l)
# Out:
# ['iti', 'BI', 3214, 'updated', 444.33, True, 'iti', ['db', 'python', 'power bi', 'freelancing'], 'iti']

# %%
# append element to a list ?
l.append("Mohamed")

# %%
#insert ??
l.insert(4, "Ghada")

# %%
l.insert(100, "ABC")

# %%
l[100]='new value'
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l[100]='new value'
#
# IndexError: list assignment index out of range

# %%
# remove ??

# 1- pop ?
popped_element = l.pop()
print(popped_element)
print(l)
# Out:
# ABC
# ['iti', 'BI', 3214, 'updated', 'Ghada', 444.33, True, 'iti', ['db', 'python', 'power bi', 'freelancing'], 'iti', 'Mohamed']

# %%
popped_element = l.pop(5) # pop element at index
print(popped_element)
# Out:
# 444.33

# %%
# remove element?
l.remove("iti")
print(l)
# Out:
# ['BI', 3214, 'updated', 'Ghada', True, 'iti', ['db', 'python', 'power bi', 'freelancing'], 'iti', 'Mohamed']

# %%
# sort list ??
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 2
#       1 # sort list ??
# ----> 2 l.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
# sort list elements  --> requires that all elements in the list must be from the same datatype

courses= ['db', 'python', 'power bi', 'freelancing']
print(courses)
courses.sort() # sort at the same variable, sort asc
print(courses)
# Out:
# ['db', 'python', 'power bi', 'freelancing']
# ['db', 'freelancing', 'power bi', 'python']

# %%
courses= ['db', 'python', 'Power bi', 'freelancing']
courses.sort(reverse=True)
print(courses)
# Out:
# ['python', 'freelancing', 'db', 'Power bi']

# %%
# reverse list ??
print(l)
l.reverse()
print(l)
# Out:
# ['BI', 3214, 'updated', 'Ghada', True, 'iti', ['db', 'python', 'power bi', 'freelancing'], 'iti', 'Mohamed']
# ['Mohamed', 'iti', ['db', 'python', 'power bi', 'freelancing'], 'iti', True, 'Ghada', 'updated', 3214, 'BI']

# %% [markdown]
# # reading list content ?

# %%
print(len(l))
# Out:
# 9

# %%
print(l.count("iti"))
print(l.index("iti"))
# Out:
# 2
# 5

# %%
# loop over list ?
for item in l:
    print(item)
# Out:
# BI
# 3214
# updated
# Ghada
# True
# iti
# ['db', 'python', 'power bi', 'freelancing']
# iti
# Mohamed

# %%
print("iti" in l)
# Out:
# True

# %%
print(l[6])
# Out:
# ['db', 'python', 'power bi', 'freelancing']

# %%
print(l[6][2])
# Out:
# power bi

# %% [markdown]
# # concat lists, extend a list

# %%
print(l)
# Out:
# ['Mohamed', 'iti', ['db', 'python', 'power bi', 'freelancing'], 'iti', True, 'Ghada', 'updated', 3214, 'BI']

# %%
newl= l + courses
print(newl)
# Out:
# ['Mohamed', 'iti', ['db', 'python', 'power bi', 'freelancing'], 'iti', True, 'Ghada', 'updated', 3214, 'BI', 'python', 'freelancing', 'db', 'Power bi']

# %%
# extend a list ?
items = ['laptop', 'iphone 17 pro max', 'Borch']
l.extend(items)
print(l)
# Out:
# ['Mohamed', 'iti', ['db', 'python', 'power bi', 'freelancing'], 'iti', True, 'Ghada', 'updated', 3214, 'BI', 'laptop', 'iphone 17 pro max', 'Borch']

# %%
# min, max ? items from the same datatype

# %%
# list with string ???
msg = "We do love python"
newmsg = list(msg)
print(newmsg)
# Out:
# ['W', 'e', ' ', 'd', 'o', ' ', 'l', 'o', 'v', 'e', ' ', 'p', 'y', 't', 'h', 'o', 'n']

# %%
# We, do
newmsg2= msg.split() # list -->> split with space
print(newmsg2)
# Out:
# ['We', 'do', 'love', 'python']

# %%
# convert list elements to a string
# all elements of the list --> string
courses= ['db', 'python', 'powerbi', 'freelancing']
res= "_".join(courses)
print(res, type(res))
# Out:
# db_python_powerbi_freelancing <class 'str'>

# %%
l.insert(1000, "Abbasss")

# %%
l.append("new Abbass")

# %%
l.insert(-1000, "new abbass 2")

# %%
# index, for each element

counter= 0
for item in l:
    print(f" index ={counter}, {item}")
    counter +=1
# Out:
#  index =0, new abbass 2
#  index =1, Mohamed
#  index =2, iti
#  index =3, ['db', 'python', 'power bi', 'freelancing']
#  index =4, iti
#  index =5, True
#  index =6, Ghada
#  index =7, updated
#  index =8, 3214
#  index =9, BI
#  index =10, laptop
#  index =11, iphone 17 pro max
#  index =12, Borch
#  index =13, Abbasss
#  index =14, new Abbass

# %%
# enumerate function
enuml = enumerate(l)
print(enuml) #iterable
# Out:
# <enumerate object at 0x76a3d7c227a0>

# %%
for item in enuml:
    print(item)
# Out:
# (0, 'new abbass 2')
# (1, 'Mohamed')
# (2, 'iti')
# (3, ['db', 'python', 'power bi', 'freelancing'])
# (4, 'iti')
# (5, True)
# (6, 'Ghada')
# (7, 'updated')
# (8, 3214)
# (9, 'BI')
# (10, 'laptop')
# (11, 'iphone 17 pro max')
# (12, 'Borch')
# (13, 'Abbasss')
# (14, 'new Abbass')

# %%
for index, item in enuml:
    print(index, item)

# %%
enuml = enumerate(l)
print(enuml) #iterable

for index, item in enuml:
    print(index, item)
# Out:
# <enumerate object at 0x76a3d7c21940>
# 0 new abbass 2
# 1 Mohamed
# 2 iti
# 3 ['db', 'python', 'power bi', 'freelancing']
# 4 iti
# 5 True
# 6 Ghada
# 7 updated
# 8 3214
# 9 BI
# 10 laptop
# 11 iphone 17 pro max
# 12 Borch
# 13 Abbasss
# 14 new Abbass
